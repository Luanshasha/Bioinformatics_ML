# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)

import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(20,8), dpi=300,facecolor=(1, 1,1))#平铺画布

plt.subplots_adjust(wspace =0.25, hspace =0.3)#调整子图间距


plt.subplot(231)
#设置 Acc,Sn,Sp,MCC
y1 = [0.790,0.770,0.780,0.560]
y2 = [0.824,0.807,0.815,0.631]
y3 = [0.890,0.871,0.880,0.761]
y4 = [0.825,0.826,0.826,0.652]
#y3 = [0.904,0.96,0.848,0.813]

ind = np.arange(4)+1.4                # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')

plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",frameon=False,fontsize=8.5)

#plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('C.elegans',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(A)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度





plt.subplot(232)
y1 = [0.833,0.790,0.812,0.620]#设置 Acc,Sn,Sp,MCC
y2 = [0.838,0.822,0.830,0.661]
y3 = [0.865,0.880,0.873,0.745]
y4 = [0.824,0.821,0.822,0.646]

ind = np.arange(4)+1.4               # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')
plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=6)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('D.melanogaster',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(B)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.subplot(233)
y1 = [0.766,0.755,0.761,0.52]#设置 Acc,Sn,Sp,MCC
y2 = [0.778,0.796,0.787,0.573]
y3 = [0.803,0.840,0.822,0.644]
y4 = [0.755,0.780,0.768,0.536]
ind = np.arange(4)+1.4                # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')

plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=6)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('A.thaliana',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(C)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.subplot(234)
y1 = [0.812,0.784,0.798,0.6]#设置 Acc,Sn,Sp,MCC
y2 = [0.858,0.807,0.832,0.666]
y3 = [0.907,0.881,0.894,0.789]
y4 = [0.819,0.832,0.826,0.655]


ind = np.arange(4)+1.4                # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')

plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=6)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('E.coli',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(D)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度



plt.subplot(235)
y1 = [0.825,0.806,0.815,0.63]#设置 Acc,Sn,Sp,MCC
y2 = [0.840,0.834,0.837,0.674]
y3 = [0.886,0.887,0.887,0.773]
y4 = [0.818,0.837,0.828,0.662]
ind = np.arange(4)+1.4                # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')

plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=6)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('G.subterraneus',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(E)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度



plt.subplot(236)
y1 = [0.819,0.861,0.840,0.68]#设置 Acc,Sn,Sp,MCC
y2 = [0.863,0.858,0.860,0.721]
y3 = [0.902,0.910,0.906,0.812]
y4 = [0.850,0.810,0.830,0.668]
ind = np.arange(4)+1.4               # the x locations for the groups
#ind = np.arange(0,10,2)
width = 0.17
plt.bar(ind,y1,width,color = '#edf8fb',label = 'iDNA4mC',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y4,width,color = '#b2e2e2',label = '4mcPred',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y2,width,color = '#66c2a4',label = "4mcPred-SVM",edgecolor = 'black')
plt.bar(ind+3*width,y3,width,color = '#238b45',label = "4mcPred-IFL",edgecolor = 'black')


plt.xticks(np.arange(4) + 10.2*width, ('SN','SP','ACC','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=6)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('G.pickeringii',fontsize=15,fontstyle='italic')#写剃头了
plt.text(0.3,0.99,'(F)',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度
plt.show()
#plt.savefig('./draw_4hist_combin.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式
