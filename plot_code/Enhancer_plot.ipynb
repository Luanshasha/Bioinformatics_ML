# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import math 
plt.figure(figsize=(15,7), dpi=300,facecolor=(1, 1, 1))#平铺画布，figsize用来设置长宽
plt.subplots_adjust(wspace =0.25, hspace =0.44)#调整子图间距

ax=plt.subplot(231)
#data = pd.read_csv("C:\Users\Lenovo\Desktop\helper\Enhancer.csv",header=None,index_col=None)
data = pd.read_csv("./data/Enhancer_plot/Enhancer.csv",header=None,index_col=None)
data = np.array(data) 
length = data[:,0][1:] 
HUVEC = list(data[:,1][1:]) 
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:])
GM12878 = list(data[:,4][1:]) 
x = range(len(length))

x_char = [] 
x_char_index=[] 
x = range(len(length)) 
for i in range((len(length)/5)+1): 
    x_char_index.append(i*5)
    x_char.append(i*5*100)

#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11)
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线


plt.title("Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(length)]) 
#设置x轴坐标 
plt.ylim((0, 0.5))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) 
#设置y轴标签 
plt.xlabel('Length',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.5, 0.05) 
plt.yticks(my_y_ticks,fontsize=8) 
#设置y轴刻度 
my_x_ticks = np.arange(0, len(length), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=8)
#设置x轴刻度 
plt.text(-0.18*len(length)*1.0,0.5,'(A)',fontsize='x-large') #在文中写字
#在文中写字 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax=plt.subplot(232)
data = pd.read_csv("./data/Enhancer_plot/Strong_Enhancer.csv",header=None,index_col=None)

data = np.array(data) 
length = data[:,0][1:] 
HUVEC = list(data[:,1][1:])
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:]) 
GM12878 = list(data[:,4][1:]) 
x = range(len(length))

x_char = [] 
x_char_index=[] 
x = range(len(length)) 
for i in range((len(length)/5)+1): 
    x_char_index.append(i*5) 
    x_char.append(i*5*100)

#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11) 
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线

#plt.plot(x,all_results)#画折线图 
plt.title("Strong_Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(length)]) #设置x轴坐标 
plt.ylim((0, 0.47))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) #设置y轴标签 
plt.xlabel('Length',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.47, 0.05) 
plt.yticks(my_y_ticks,fontsize=8) #设置y轴刻度
my_x_ticks = np.arange(0, len(length), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=8)#设置x轴刻度 
plt.text(-0.19*len(length)*1.0,0.47,'(B)',fontsize='x-large') 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax=plt.subplot(233)
data = pd.read_csv("./data/Enhancer_plot/weka_Enhancer.csv",header=None,index_col=None)


data = np.array(data) 
length = data[:,0][1:] 
HUVEC = list(data[:,1][1:])
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:]) 
GM12878 = list(data[:,4][1:]) 
x = range(len(length))

x_char = [] 
x_char_index=[] 
x = range(len(length)) 
for i in range((len(length)/3)+1): 
    x_char_index.append(i*3) 
    x_char.append(i*3*100)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11) 
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线

#plt.plot(x,all_results)#画折线图 
plt.title("Weak_Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(length)]) #设置x轴坐标 
plt.ylim((0, 0.53))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) #设置y轴标签 
plt.xlabel('Length',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.53, 0.05) 
plt.yticks(my_y_ticks,fontsize=8) #设置y轴刻度
my_x_ticks = np.arange(0, len(length), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=8)#设置x轴刻度 
plt.text(-0.19*len(length)*1.0,0.53,'(C)',fontsize='x-large') 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)







ax=plt.subplot(234)
data = pd.read_csv("./data/Enhancer_plot/GC_Enhancer.csv",header=None,index_col=None)

data = np.array(data) 
GC_num = data[:,0][1:] 
HUVEC = list(data[:,1][1:]) 
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:])
GM12878 = list(data[:,4][1:]) 
x = range(len(GC_num))

x_char = [] 
x_char_index=[] 
x = range(len(GC_num)) 

for i in range((len(GC_num)/5)+1): 
    x_char_index.append(i*5)
    x_char.append(float(i*5*2))

x_char = [i/100 for i in x_char]

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11)
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线


plt.title("Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(GC_num)]) 
#设置x轴坐标 
plt.ylim((0, 0.124))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) 
#设置y轴标签 
plt.xlabel('GC-content',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.124, 0.02) 
plt.yticks(my_y_ticks,fontsize=9) 
#设置y轴刻度 
my_x_ticks = np.arange(0, len(GC_num), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=9)
#设置x轴刻度 
plt.text(-0.19*len(GC_num)*1.0,0.124,'(D)',fontsize='x-large') #在文中写字
#在文中写字 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax=plt.subplot(235)
data = pd.read_csv("./data/Enhancer_plot/GC_Strong_Enhancer.csv",header=None,index_col=None)

data = np.array(data) 
GC_num = data[:,0][1:] 
HUVEC = list(data[:,1][1:]) 
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:])
GM12878 = list(data[:,4][1:]) 
x = range(len(GC_num))

x_char = [] 
x_char_index=[] 
x = range(len(GC_num)) 

for i in range((len(GC_num)/5)+1): 
    x_char_index.append(i*5)
    x_char.append(float(i*5*2))

x_char = [i/100 for i in x_char]

  

#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11)
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线


plt.title("Strong_Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(GC_num)]) 
#设置x轴坐标 
plt.ylim((0, 0.132))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) 
#设置y轴标签 
plt.xlabel('GC-content',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.132, 0.02) 
plt.yticks(my_y_ticks,fontsize=9) 
#设置y轴刻度 
my_x_ticks = np.arange(0, len(GC_num), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=9)
#设置x轴刻度 
plt.text(-0.18*len(GC_num)*1.0,0.132,'(E)',fontsize='x-large') #在文中写字
#在文中写字 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax=plt.subplot(236)
data = pd.read_csv("./data/Enhancer_plot/GC_Weak_Enhancer.csv",header=None,index_col=None)

data = np.array(data) 
GC_num = data[:,0][1:] 
HUVEC = list(data[:,1][1:]) 
NHEK = list(data[:,2][1:])
K562 = list(data[:,3][1:])
GM12878 = list(data[:,4][1:]) 
x = range(len(GC_num))

x_char = [] 
x_char_index=[] 
x = range(len(GC_num)) 
for i in range((len(GC_num)/5)+1): 
    x_char_index.append(i*5)
    x_char.append(float(i*5*2))
x_char = [i/100 for i in x_char]

  

#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置

#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-12,max_value),xy=(max_value_index,max_value),fontsize=11)
plt.plot(x,HUVEC,color='#e41a1c',label="HUVEC")#画直线 
plt.plot(x,NHEK,color='#377eb8',label="NHEK")#画直线 
plt.plot(x,K562,color='#4daf4a',label="K562")#画直线 
plt.plot(x,GM12878,color='#984ea3',label="GM12878")#画直线


plt.title("Weak_Enhancer",fontsize=12)#设置剃头了 
plt.legend(loc="upper right",fontsize=10)#设置legend的位置，这边表示右上

#设置坐标轴范围 
plt.xlim([0, len(GC_num)]) 
#设置x轴坐标 
plt.ylim((0, 0.115))#设置 y轴坐标

#设置坐标轴名称 
plt.ylabel('proportion',fontsize=12) 
#设置y轴标签 
plt.xlabel('GC-content',fontsize=12)#设置x轴标签

#设置坐标轴刻度 
my_y_ticks = np.arange(0, 0.115, 0.02) 
plt.yticks(my_y_ticks,fontsize=9) 
#设置y轴刻度 
my_x_ticks = np.arange(0, len(GC_num), 5) 
plt.xticks(x_char_index, x_char, rotation=45,fontsize=9)
#设置x轴刻度 
plt.text(-0.18*len(GC_num)*1.0,0.115,'(F)',fontsize='x-large') #在文中写字
#在文中写字 
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.show()

#plt.savefig('./Enhancer_GC_no_frame.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式
