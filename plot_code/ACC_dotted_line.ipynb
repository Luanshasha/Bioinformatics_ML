# %%
# used as plot program
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
plt.figure(figsize=(15,6), dpi=300,facecolor=(1, 1, 1))#平铺画布，figsize用来设置长宽
# plt.tight_layout()#调整整体空白
plt.subplots_adjust(wspace =0.35, hspace =0.5)#调整子图间距
ax=plt.subplot(231)
# plt.plot(x,np.sin(x))
#data = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.csv",header=None,index_col=None)
data = pd.read_csv("./data/ACC_dotted_line/S1_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(max_value_index)
max_value=round(max_value,4)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-8,max_value-0.02),xy=(max_value_index,max_value),fontsize=11)


### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("C.elegans",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc="lower right",fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8, length_x]) #设置x轴坐标
plt.ylim((0.82, 0.884))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.82, 0.884, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.08*length_x*1.0,0.884,'(A)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax=plt.subplot(232)
x=np.arange(1,10,0.01)
# plt.plot(x,np.sin(x))
data = pd.read_csv("./data/ACC_dotted_line/S2_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(max_value_index)
max_value=round(max_value,4)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index+0.5,max_value-0.015),xy=(max_value_index,max_value),fontsize=12)
#plt.plot([max_value_index,max_value_index],[0,max_value],color="red",label="Best ACC: %.4f"%max_value)#画直线

### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("D.melanogaster",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc="lower right",fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8, length_x]) #设置x轴坐标
plt.ylim((0.825, 0.876))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.825, 0.876, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.1*length_x*1.0,0.876,'(B)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax=plt.subplot(233)
x=np.arange(1,10,0.01)
# plt.plot(x,np.sin(x))
data = pd.read_csv("./data/ACC_dotted_line/S3_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(max_value_index)
max_value=round(max_value,4)
#plt.plot([max_value_index,max_value_index],[0,max_value],color="red",label="Best ACC: %.4f"%max_value)#画直线

#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-10,max_value-0.015),xy=(max_value_index,max_value),fontsize=11)


### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("A.thaliana",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc="lower right",bbox_to_anchor=(1.015, 0.005),fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8, length_x]) #设置x轴坐标
plt.ylim((0.785, 0.825))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.785, 0.825, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.1*length_x*1.0,0.825,'(C)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax=plt.subplot(234)
x=np.arange(1,10,0.01)
# plt.plot(x,np.sin(x))
data = pd.read_csv("./data/ACC_dotted_line/S4_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(max_value_index)
max_value=round(max_value,4)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-15.5,max_value-0.018),xy=(max_value_index,max_value),fontsize=11)
#plt.plot([max_value_index,max_value_index],[0,max_value],color="red",label="Best ACC: %.4f"%max_value)#画直线

### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("E.coli",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc="lower right",fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8, length_x]) #设置x轴坐标
plt.ylim((0.834, 0.896))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.834, 0.896, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.1*length_x*1.0,0.896,'(D)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax=plt.subplot(235)
x=np.arange(1,10,0.01)
# plt.plot(x,np.sin(x))
data = pd.read_csv("./data/ACC_dotted_line/S5_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(max_value_index)
max_value=round(max_value,4)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-10.9,max_value-0.022),xy=(max_value_index,max_value),fontsize=12)
#plt.plot([max_value_index,max_value_index],[0,max_value],color="red",label="Best ACC: %.4f"%max_value)#画直线

### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("G.subterraneus",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc='lower right',fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8, length_x]) #设置x轴坐标
plt.ylim((0.836, 0.89))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.836, 0.89, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.1*length_x*1.0,0.89,'(E)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)




ax=plt.subplot(236)
x=np.arange(1,10,0.01)
# plt.plot(x,np.sin(x))
data = pd.read_csv("./data/ACC_dotted_line/S6_ACC.csv",header=None,index_col=None)
'''file_location="C:\\Users\\Lenovo\\Desktop\\XXXplot\\S1_ACC.txt"
all_results=[]
with open(file_location,'r') as f:#默认打开模式就为r
    data=f.readlines()
    for yy in data:
        all_results.append(yy)#读取文件，进行文件处理，这一步需要自己实现
all_results
print(all_results)'''
#x=range(len(all_results))
data = np.array(data)
x = [i for i in data[:,0]]
all_results = list(data[:,1])
#x= list(map(lambda x: x*10, range(len(all_results))))
length_x=max(x)+3
max_value=max(all_results)
max_value_index=int(x[all_results.index(max_value)])
print(int(max_value_index))
max_value=round(max_value,4)


#plt.annotata表示在图中写字，第一个参数就是显示的内容，第二个人参数xytext为位置
#plt.annotate("["+str(max_value_index)+","+str(max_value)+"]",xytext=(max_value_index-10,max_value-0.015),xy=(max_value_index,max_value),fontsize=11)
#plt.plot([max_value_index,max_value_index],[0,max_value],color="red",label="Best ACC: %.4f"%max_value)#画直线

### 画的是被比较的acc
#max_value1=0.815315315
#plt.annotate("["+str(max_value1)+"]",xytext=(max_value_index+3,max_value-0.1),xy=(max_value_index+5,max_value1),fontsize=5)
#plt.plot([max_value_index+5,max_value_index+5],[0,max_value1],color="orange",label="4mcPred-SVM_Best ACC: %.8f"%max_value1)#画直线

plt.plot(x,all_results,marker='o',linestyle='-',color='#4daf4a')#画折线图
plt.plot(max_value_index,max_value,marker='o',color="red")#画直线
plt.title("G.pickeringii",fontsize=12,fontstyle='italic')#设置剃头了
plt.legend(loc="lower right",fontsize=11)#设置legend的位置，这边表示右上

#设置坐标轴范围

plt.xlim([8,length_x]) #设置x轴坐标
plt.ylim((0.864, 0.91))#设置  y轴坐标
#设置坐标轴名称
plt.ylabel('Accuracy',fontsize=12) #设置y轴标签
plt.xlabel('feature dimension',fontsize=12)#设置x轴标签
#设置坐标轴刻度
my_y_ticks = np.arange(0.864, 0.91, 0.01)
plt.yticks(my_y_ticks) #设置y轴刻度
my_x_ticks = np.arange(8, length_x, 5)
plt.xticks(my_x_ticks)#设置x轴刻度
plt.text(-0.10*length_x*1.0,0.91,'(F)',fontsize='x-large') #在文中写字
plt.tick_params(top='off', right='off', which='both') #关掉右边和上边的刻度线
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()
#plt.savefig('./4mcPred_IFL_ACC1.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式
# Out:
# 37
# 34
# 21
# 67
# 35
# 60
