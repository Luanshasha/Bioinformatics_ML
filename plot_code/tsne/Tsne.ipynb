# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

plt.figure(figsize=(12,25), dpi=300,facecolor=(1, 1, 1))#平铺画布，设置dpi300,注意，发表文章dpi不能低于300

#adjust distrances of subplots
plt.subplots_adjust(wspace =0.3, hspace =0.4)#调节子图之间的宽度 
model=TSNE(n_components=2,random_state=0)

ax2=plt.subplot(621)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S1_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S1_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('C.elegans_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(A)',fontsize='13')
plt.xlim((-78, 78))###对应before_tsne.ipynb文件生成结果中的Dimension1的范围
plt.ylim((-78, 88))###对应before_tsne.ipynb文件生成结果中的Dimension2的范围


ax2=plt.subplot(622)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S1_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S1_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('C.elegans_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(B)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-78, 88))


ax2=plt.subplot(623)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S2_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S2_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('D.melanogaster_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(C)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-98, 88))


ax2=plt.subplot(624)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S2_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S2_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('D.melanogaster_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(D)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-98, 88))



ax2=plt.subplot(625)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S3_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S3_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('A.thaliana_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-128,80,'(E)',fontsize='13')
plt.xlim((-98, 98))
plt.ylim((-78, 88))


ax2=plt.subplot(626)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S2_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S2_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('A.thaliana_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(F)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-88, 88))



ax2=plt.subplot(627)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S4_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S4_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('E.coli_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-86,80,'(G)',fontsize='13')
plt.xlim((-68, 68))
plt.ylim((-68, 78))


ax2=plt.subplot(6,2,8)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S4_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S4_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('E.coli_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-88,80,'(H)',fontsize='13')
plt.xlim((-68, 68))
plt.ylim((-68, 78))


ax2=plt.subplot(629)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S5_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S5_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('G.subterraneus_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-99,80,'(I)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-88, 88))


ax2=plt.subplot(6,2,10)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S5_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S5_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('G.subterraneus_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-100,80,'(J)',fontsize='13')
plt.xlim((-78, 78))
plt.ylim((-78, 88))



ax2=plt.subplot(6,2,11)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S6_initial.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S6_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('G.pickeringii_initial',fontsize=12)
plt.legend(loc="upper right")
plt.text(-87,80,'(K)',fontsize='13')
plt.xlim((-68, 68))
plt.ylim((-68, 78))


ax2=plt.subplot(6,2,12)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
data1=pd.read_csv(r"./my_article_tsne/S6_stable.csv",header=None,index_col=None)
labels1=pd.read_csv(r"./my_article_tsne/S6_label.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label=="Positive") ]
p2=tsne_df[(tsne_df.label=="Negative") ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='4')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='4')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('G.pickeringii_stable',fontsize=12)
plt.legend(loc="upper right")
plt.text(-86,80,'(L)',fontsize='13')
plt.xlim((-68, 68))
plt.ylim((-68, 78))




plt.show()
#plt.savefig('./my_article_results/t-sne—all1.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式

# %%
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# from sklearn.manifold import TSNE

    
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)2.csv",header=None,index_col=None)
# # label1=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=2)3.csv",header=None,index_col=None)
# # model=TSNE(n_components=2,random_state=0)
# tsne_data1=model.fit_transform(data1)
# tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
# tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
# data2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=4).csv",header=None,index_col=None)
# labels2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=4)2.csv",header=None,index_col=None)
# label2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NT=4)3.csv",header=None,index_col=None)
# model=TSNE(n_components=2,random_state=0)
# tsne_data2=model.fit_transform(data2)
# tsne_data2=np.vstack((tsne_data2.T,labels2.T,label2.T)).T

# data3=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit21(NT=2).csv",header=None,index_col=None)
# labels3=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit21(NT=2)2.csv",header=None,index_col=None)
# label3=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit21(NT=2)3.csv",header=None,index_col=None)
# model=TSNE(n_components=2,random_state=0)
# tsne_data3=model.fit_transform(data3)
# tsne_data3=np.vstack((tsne_data3.T,labels3.T,label3.T)).T
# tsne_datak=np.vstack((tsne_data1,tsne_data2))
# tsne_datak=np.vstack((tsne_data,tsne_data3))

# tsne_data=np.vstack((tsne_data.T,labels.T).T
# print tsne_data


# tsne_df=pd.DataFrame(data=tsne_datak,columns=("Dimension1","Dimension2","label","Method"))
# print tsne_df
# ax=plt.subplot(331)
# g =sns.FacetGrid(tsne_df,hue="label",col="Method",size=5,legend_out=True,).map(plt.scatter,"Dimension1","Dimension2").add_legend()
# g =sns.FacetGrid(tsne_df,hue="label",col="label1",size=5,legend_out=True,).map(plt.scatter,"Dimension1","Dimension2").add_legend()


# data4=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=2).csv",header=None,index_col=None)
# labels4=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=2)2.csv",header=None,index_col=None)
# label4=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=2)3.csv",header=None,index_col=None)
# model=TSNE(n_components=2,random_state=0)
# tsne_data4=model.fit_transform(data4)
# tsne_data4=np.vstack((tsne_data4.T,labels4.T,label4.T)).T


# data5=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=3).csv",header=None,index_col=None)
# labels5=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=3)2.csv",header=None,index_col=None)
# label5=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\Bit20(NTCT=3)3.csv",header=None,index_col=None)
# model=TSNE(n_components=2,random_state=0)
# tsne_data5=model.fit_transform(data5)
# tsne_data5=np.vstack((tsne_data5.T,labels5.T,label5.T)).T

# data6=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\FT62.csv",header=None,index_col=None)
# labels6=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\FT622.csv",header=None,index_col=None)
# label6=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\Tse\FT623.csv",header=None,index_col=None)
# model=TSNE(n_components=2,random_state=0)
# tsne_data6=model.fit_transform(data6)
# tsne_data6=np.vstack((tsne_data6.T,labels6.T,label6.T)).T
# tsne_datak2=np.vstack((tsne_data4,tsne_data5))
# tsne_datak2=np.vstack((tsne_datak2,tsne_data6))


# tsne_datak=np.vstack((tsne_datak,tsne_datak2))
# tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))



# # g =sns.FacetGrid(tsne_df,hue="label",col="Method",size=3, col_wrap=2,legend_out=True,).map(plt.scatter,"Dimension1","Dimension2").add_legend()
# fig = plt.figure()  
# ax = fig.add_subplot(111)
# p1=tsne_df[(tsne_df.label=="Positive") ]
# p2=tsne_df[(tsne_df.label=="Negative") ]
# x1=p1.values[:,0]
# y1=p1.values[:,1]
# x2=p2.values[:,0]
# y2=p2.values[:,1]
# # data2=tsne_df[["Dimension2"| (Method=="Bit20(NTCT=2)")]]
# # data2=tsne_df[0:20,1]

# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')
