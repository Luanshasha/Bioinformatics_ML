# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(15,6), dpi=300,facecolor=(1, 1, 1))#设置画布长宽，论文发表的dpi最小为300
# plt.tight_layout()#调整整体空白
plt.subplots_adjust(wspace =0.35, hspace =0.5)#调整子图间距
# plt.subplots()
# plt.tight_layout(h_pad=1.08)



plt.subplot(231)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S1_DataRelyS1_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('C.elegans',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(A)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10




plt.subplot(232)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('D.melanogaster',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(B)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10



plt.subplot(233)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S3_DataRelyS3_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S2_DataRelyS2_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S3_DataRelyS3_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S3_DataRelyS3_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S3_DataRelyS3_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S3_DataRelyS3_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('A.thaliana',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(C)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10

plt.subplot(234)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S4_DataRelyS4_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('E.coli',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(D)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10


plt.subplot(235)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S5_DataRealyS5_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('G.subterraneus',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(E)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10



plt.subplot(236)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_GBDT_predict.csv",header=None,index_col=None)# 加载的数据位csv格式，第一列是真实的标签值，第二列是预测值，第三列是预测分数
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])# 提取真实标签值和预测分数代进roc_curve做参数
roc_auc = auc(fpr, tpr)#得到roc值
plt.plot(fpr, tpr,'r-.',color = '#D2691E',label=r'GBDT(AUC=%.3f)'%roc_auc)#绘制曲线，设置颜色为#005344，还有要显示在legend里面的内容
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_KNN_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#FAA460',label=r'KNN(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_LR_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#F0E68C',label=r'LR(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_NB_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#90EE90',label=r'NB(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#66CDAA',label=r'RF(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"./data/MultipleClassifierResults_ROC/S6_DataRelyS6_SVM_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#4682B4',label=r'SVM(AUC=%.3f)'%roc_auc)
plt.xlim([0, 1])#设置x轴长度
plt.ylim([0, 1])#设置y轴长度
plt.xticks(fontsize=11)#设置x轴字体大小
plt.yticks(fontsize=11)#设置y轴字体大小
plt.xlabel('False Positive Rate',fontsize=11)#设置x轴标签
plt.ylabel('True Positive Rate',fontsize=11)#设置y轴标签
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize=6)
plt.title('G.pickeringii',fontsize=12)#设置title
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.24,0.99,'(F)',fontsize=13)#途中画质，前两个数值代表位置，fontsize为字体大小
plt.legend(loc="lower right",fontsize=10)#设置legend在右下，字体为10


#plt.savefig('./MultipleClassifier_ROC_amend3.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式
#print("done")
plt.show()
