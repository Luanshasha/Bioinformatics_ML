# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)

import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(15,6), dpi=300,facecolor=(1, 1,1))#平铺画布

plt.subplots_adjust(wspace =0.35, hspace =0.35)#调整子图间距


plt.subplot(231)
y1 = [0.796,0.803,0.790,0.593]#设置 Acc,Sn,Sp,MCC
y2 = [0.815,0.823,0.807,0.631]
#y3 = [0.904,0.96,0.848,0.813]

ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('C.elegans',fontsize=13)#写剃头了
plt.text(0.2,0.99,'A',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度



plt.subplot(232)
y1 = [0.820,0.837,0.803,0.640]#设置 Acc,Sn,Sp,MCC
y2 = [0.830,0.838,0.822,0.661]
ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('D.melanogaster',fontsize=13)#写剃头了
plt.text(0.2,0.99,'B',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.subplot(233)
y1 = [0.775,0.771,0.779,0.549]#设置 Acc,Sn,Sp,MCC
y2 = [0.787,0.778,0.796,0.573]
#y3 = [0.904,0.96,0.848,0.813]
ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置

# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('A.thaliana',fontsize=13)#写剃头了
plt.text(0.2,0.99,'C',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.subplot(234)
y1 = [0.799,0.814,0.784,0.598]#设置 Acc,Sn,Sp,MCC
y2 = [0.835,0.845,0.825,0.670]
#y3 = [0.904,0.96,0.848,0.813]
ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('E.coli',fontsize=13)#写剃头了
plt.text(0.2,0.99,'D',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.subplot(235)
y1 = [0.827,0.828,0.827,0.655]#设置 Acc,Sn,Sp,MCC
y2 = [0.845,0.841,0.850,0.691]
#y3 = [0.904,0.96,0.848,0.813]
ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('G.subterraneus',fontsize=13)#写剃头了
plt.text(0.2,0.99,'E',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度




plt.subplot(236)
y1 = [0.837,0.831,0.843,0.675]#设置 Acc,Sn,Sp,MCC
y2 = [0.864,0.875,0.852,0.728]
#y3 = [0.904,0.96,0.848,0.813]
ind = np.arange(4)+1.25               # the x locations for the groups
width = 0.25
plt.bar(ind,y1,width,color = '#F0E68C',label = 'Before',edgecolor = 'black')  #绘制直方图，ind表示哪些位置，y1表示高度，width表示宽度
plt.bar(ind+width,y2,width,color = '#4682B4',label = 'After',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
#plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SVM",edgecolor = 'black')
plt.xticks(np.arange(4) + 5.5*width, ('ACC','SN','SP','MCC'),fontsize=11)#x轴下表，第一个参数为位置
# plt.legend(loc="upper right",bb.ox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
#plt.legend(loc="upper left",fontsize=10)
# plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('G.pickeringii',fontsize=13)#写剃头了
plt.text(0.2,0.99,'F',fontsize='xx-large')#图片中写字
# Independent Test
plt.ylim(0.45, 1)#设置y轴长度


plt.show()
#plt.savefig('./draw_2hist.pdf',bbox_inches='tight')#不能跟plt.show同时用，可用来保存svg,pdf,tiff等格式
